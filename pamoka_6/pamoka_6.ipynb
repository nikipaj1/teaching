# %% [markdown]
# # 6 Pamoka: Pandas #2

# %%
# !pip3 install pandas
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Trukstami Duomenys

# %%
df = pd.DataFrame(np.random.rand(5,6), 
                ['a', 'b', 'c', 'd', 'e'], 
                ['U', 'V', 'W', 'X', 'Y', 'Z'])

# %%
df
# Out:
#           U         V         W         X         Y         Z
# a  0.922965  0.133949  0.299491  0.221957  0.084694  0.598735
# b  0.372609  0.739499  0.926529  0.784357  0.897677  0.163551
# c  0.016958  0.310164  0.381014  0.816599  0.484805  0.205125
# d  0.403751  0.085628  0.384796  0.132179  0.432360  0.026625
# e  0.547058  0.370504  0.473615  0.619465  0.470644  0.190577

# %%
table = df[df > 0.15]

# %%
table
# Out:
#           U         V         W         X         Y         Z
# a  0.922965       NaN  0.299491  0.221957       NaN  0.598735
# b  0.372609  0.739499  0.926529  0.784357  0.897677  0.163551
# c       NaN  0.310164  0.381014  0.816599  0.484805  0.205125
# d  0.403751       NaN  0.384796       NaN  0.432360       NaN
# e  0.547058  0.370504  0.473615  0.619465  0.470644  0.190577

# %%
table.isnull()
# Out:
#        U      V      W      X      Y      Z
# a  False   True  False  False   True  False
# b  False  False  False  False  False  False
# c   True  False  False  False  False  False
# d  False   True  False   True  False   True
# e  False  False  False  False  False  False

# %%
table.isnull().sum()
# Out:
# U    1
# V    2
# W    0
# X    1
# Y    1
# Z    1
# dtype: int64

# %%
False == 0
# Out:
# True

# %%
True == 1
# Out:
# True

# %%
table['V'].isnull()
# Out:
# a     True
# b    False
# c    False
# d     True
# e    False
# Name: V, dtype: bool

# %%
table['V'].isnull().sum()
# Out:
# 2

# %%
table.dropna()
# Out:
#           U         V         W         X         Y         Z
# b  0.372609  0.739499  0.926529  0.784357  0.897677  0.163551
# e  0.547058  0.370504  0.473615  0.619465  0.470644  0.190577

# %%
table.dropna(axis=1)
# Out:
#           W
# a  0.299491
# b  0.926529
# c  0.381014
# d  0.384796
# e  0.473615

# %%
table.dropna(thresh=5)
# Out:
#           U         V         W         X         Y         Z
# b  0.372609  0.739499  0.926529  0.784357  0.897677  0.163551
# c       NaN  0.310164  0.381014  0.816599  0.484805  0.205125
# e  0.547058  0.370504  0.473615  0.619465  0.470644  0.190577

# %% [markdown]
# Null reiksmiu uzpildymas

# %%
table.fillna('not a null')
# Out:
#             U           V         W           X           Y           Z
# a    0.922965  not a null  0.299491    0.221957  not a null    0.598735
# b    0.372609    0.739499  0.926529    0.784357    0.897677    0.163551
# c  not a null    0.310164  0.381014    0.816599    0.484805    0.205125
# d    0.403751  not a null  0.384796  not a null     0.43236  not a null
# e    0.547058    0.370504  0.473615    0.619465    0.470644    0.190577

# %%
table['X'].mean()
# Out:
# 0.61059432744093

# %% [markdown]
# `vidutines reiksmes priskyrimas`: norime priskirti vidutine reiksme stulpeliui

# %%
table['X'].fillna(value=table['X'].mean())
# Out:
# a    0.221957
# b    0.784357
# c    0.816599
# d    0.610594
# e    0.619465
# Name: X, dtype: float64

# %% [markdown]
# `savo reiksmes priskyrimas`

# %%
table['U'].fillna(1.0)
# Out:
# a    0.922965
# b    0.372609
# c    1.000000
# d    0.403751
# e    0.547058
# Name: U, dtype: float64

# %% [markdown]
# ## Grupavimas

# %%
duomenys = {'Šalis': ['Lietuva',
  'Lietuva',
  'Lietuva',
  'Latvija',
  'Latvija',
  'Latvija',
  'Estija',
  'Estija',
  'Estija'],
 'Miestas': ['Vilnius',
  'Kaunas',
  'Klaipėda',
  'Ryga',
  'Ventspilis',
  'Daugpilis',
  'Talinas',
  'Tartu',
  'Pernu'],
 'Gyv': [541, 287, 147, 716, 43, 105, 400, 101, 46]}

# %%
df = pd.DataFrame(duomenys)

# %%
df.groupby("Šalis")

# %%
df.groupby("Šalis").mean()
# Out:
# /var/folders/9h/pxgsfw7n1h1bdydh77wmr1q40000gn/T/ipykernel_16701/2358123355.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Šalis").mean()
#                 Gyv
# Šalis
# Estija   182.333333
# Latvija  288.000000
# Lietuva  325.000000

# %%
df.groupby("Šalis").sum()
# Out:
# /var/folders/9h/pxgsfw7n1h1bdydh77wmr1q40000gn/T/ipykernel_16701/319958757.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Šalis").sum()
#          Gyv
# Šalis
# Estija   547
# Latvija  864
# Lietuva  975

# %%
df.groupby("Šalis").count()
# Out:
#          Miestas  Gyv
# Šalis
# Estija         3    3
# Latvija        3    3
# Lietuva        3    3

# %%
df.groupby("Šalis").max()
# Out:
#             Miestas  Gyv
# Šalis
# Estija        Tartu  400
# Latvija  Ventspilis  716
# Lietuva     Vilnius  541

# %%
df.groupby("Šalis").min()
# Out:
#            Miestas  Gyv
# Šalis
# Estija       Pernu   46
# Latvija  Daugpilis   43
# Lietuva     Kaunas  147

# %%
df.groupby("Šalis").agg({'Miestas': 'count', 'Gyv': 'min'})
# Out:
#          Miestas  Gyv
# Šalis
# Estija         3   46
# Latvija        3   43
# Lietuva        3  147

# %%
df.groupby("Šalis").sum().loc['Lietuva']
# Out:
# /var/folders/9h/pxgsfw7n1h1bdydh77wmr1q40000gn/T/ipykernel_16701/1413998473.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Šalis").sum().loc['Lietuva']
# Gyv    975
# Name: Lietuva, dtype: int64

# %%
df.groupby("Šalis").describe()
# Out:
#           Gyv
#         count        mean         std    min    25%    50%    75%    max
# Šalis
# Estija    3.0  182.333333  190.500219   46.0   73.5  101.0  250.5  400.0
# Latvija   3.0  288.000000  371.952954   43.0   74.0  105.0  410.5  716.0
# Lietuva   3.0  325.000000  199.729818  147.0  217.0  287.0  414.0  541.0

# %%
df.groupby("Šalis").describe().transpose()
# Out:
# Šalis          Estija     Latvija     Lietuva
# Gyv count    3.000000    3.000000    3.000000
#     mean   182.333333  288.000000  325.000000
#     std    190.500219  371.952954  199.729818
#     min     46.000000   43.000000  147.000000
#     25%     73.500000   74.000000  217.000000
#     50%    101.000000  105.000000  287.000000
#     75%    250.500000  410.500000  414.000000
#     max    400.000000  716.000000  541.000000

# %%
df.groupby("Šalis").describe().transpose()['Estija']
# Out:
# Gyv  count      3.000000
#      mean     182.333333
#      std      190.500219
#      min       46.000000
#      25%       73.500000
#      50%      101.000000
#      75%      250.500000
#      max      400.000000
# Name: Estija, dtype: float64

# %% [markdown]
# ## Dataframe jungimas

# %%
df1 = df[0:6]

# %%
df1
# Out:
#      Šalis     Miestas  Gyv
# 0  Lietuva     Vilnius  541
# 1  Lietuva      Kaunas  287
# 2  Lietuva    Klaipėda  147
# 3  Latvija        Ryga  716
# 4  Latvija  Ventspilis   43
# 5  Latvija   Daugpilis  105

# %%
df2 = df[6:]

# %%
df2
# Out:
#     Šalis  Miestas  Gyv
# 6  Estija  Talinas  400
# 7  Estija    Tartu  101
# 8  Estija    Pernu   46

# %% [markdown]
# `Komentaras`: atsrgiai su duplikatais

# %%
pd.concat([df1, df2])    # .drop_duplicates() jeigu potencialiai gali lenta tureti identisku eiluciu
                         # .drop_duplicates(subset='Miestas')
# Out:
#      Šalis     Miestas  Gyv
# 0  Lietuva     Vilnius  541
# 1  Lietuva      Kaunas  287
# 2  Lietuva    Klaipėda  147
# 3  Latvija        Ryga  716
# 4  Latvija  Ventspilis   43
# 5  Latvija   Daugpilis  105
# 6   Estija     Talinas  400
# 7   Estija       Tartu  101
# 8   Estija       Pernu   46

# %% [markdown]
# Jungimas is desines

# %%
pd.concat([df1, df2], axis=1)
# Out:
#      Šalis     Miestas    Gyv   Šalis  Miestas    Gyv
# 0  Lietuva     Vilnius  541.0     NaN      NaN    NaN
# 1  Lietuva      Kaunas  287.0     NaN      NaN    NaN
# 2  Lietuva    Klaipėda  147.0     NaN      NaN    NaN
# 3  Latvija        Ryga  716.0     NaN      NaN    NaN
# 4  Latvija  Ventspilis   43.0     NaN      NaN    NaN
# 5  Latvija   Daugpilis  105.0     NaN      NaN    NaN
# 6      NaN         NaN    NaN  Estija  Talinas  400.0
# 7      NaN         NaN    NaN  Estija    Tartu  101.0
# 8      NaN         NaN    NaN  Estija    Pernu   46.0

# %%
data_right = df2.reset_index(drop=True)

# %%
data_right
# Out:
#     Šalis  Miestas  Gyv
# 0  Estija  Talinas  400
# 1  Estija    Tartu  101
# 2  Estija    Pernu   46

# %%
pd.concat([df1, data_right], axis=1)
# Out:
#      Šalis     Miestas  Gyv   Šalis  Miestas    Gyv
# 0  Lietuva     Vilnius  541  Estija  Talinas  400.0
# 1  Lietuva      Kaunas  287  Estija    Tartu  101.0
# 2  Lietuva    Klaipėda  147  Estija    Pernu   46.0
# 3  Latvija        Ryga  716     NaN      NaN    NaN
# 4  Latvija  Ventspilis   43     NaN      NaN    NaN
# 5  Latvija   Daugpilis  105     NaN      NaN    NaN

# %% [markdown]
# ## Join / Merge

# %%
key = 'A B C D E F'.split()
df1['key'] = key
# data_right['key'] = key
# Out:
# /var/folders/9h/pxgsfw7n1h1bdydh77wmr1q40000gn/T/ipykernel_16701/3519981816.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['key'] = key

# %%
df1
# Out:
#      Šalis     Miestas  Gyv key
# 0  Lietuva     Vilnius  541   A
# 1  Lietuva      Kaunas  287   B
# 2  Lietuva    Klaipėda  147   C
# 3  Latvija        Ryga  716   D
# 4  Latvija  Ventspilis   43   E
# 5  Latvija   Daugpilis  105   F

# %%
df3 = df[2:8]

# %%
df3['key'] = key
# Out:
# /var/folders/9h/pxgsfw7n1h1bdydh77wmr1q40000gn/T/ipykernel_16701/1373257844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['key'] = key

# %%
df4 = df3.copy()

# %%
df4.columns = ['Šalis', 'City', 'Gyv', 'key']

# %%
df4.columns = ['Šalis', 'Miestas', 'Gyv', 'key']

# %%
df4
# Out:
#      Šalis     Miestas  Gyv key
# 2  Lietuva    Klaipėda  147   A
# 3  Latvija        Ryga  716   B
# 4  Latvija  Ventspilis   43   C
# 5  Latvija   Daugpilis  105   D
# 6   Estija     Talinas  400   E
# 7   Estija       Tartu  101   F

# %%
pd.merge(df1, df4, on='key')
# Out:
#    Šalis_x     Miestas  Gyv_x key  Šalis_y        City  Gyv_y
# 0  Lietuva     Vilnius    541   A  Lietuva    Klaipėda    147
# 1  Lietuva      Kaunas    287   B  Latvija        Ryga    716
# 2  Lietuva    Klaipėda    147   C  Latvija  Ventspilis     43
# 3  Latvija        Ryga    716   D  Latvija   Daugpilis    105
# 4  Latvija  Ventspilis     43   E   Estija     Talinas    400
# 5  Latvija   Daugpilis    105   F   Estija       Tartu    101

# %% [markdown]
# Jeigu reiksmes skiriasi

# %%
keyX = 'X Y Z D E F'.split()

# %%
df4['key'] = keyX

# %%
df4
# Out:
#      Šalis     Miestas  Gyv key
# 2  Lietuva    Klaipėda  147   X
# 3  Latvija        Ryga  716   Y
# 4  Latvija  Ventspilis   43   Z
# 5  Latvija   Daugpilis  105   D
# 6   Estija     Talinas  400   E
# 7   Estija       Tartu  101   F

# %%
pd.merge(df1, df4, on='key')
# Out:
#    Šalis_x   Miestas_x  Gyv_x key  Šalis_y  Miestas_y  Gyv_y
# 0  Latvija        Ryga    716   D  Latvija  Daugpilis    105
# 1  Latvija  Ventspilis     43   E   Estija    Talinas    400
# 2  Latvija   Daugpilis    105   F   Estija      Tartu    101

# %%
pd.merge(df1, df4, on='key', how='outer')
# Out:
#    Šalis_x   Miestas_x  Gyv_x key  Šalis_y   Miestas_y  Gyv_y
# 0  Lietuva     Vilnius  541.0   A      NaN         NaN    NaN
# 1  Lietuva      Kaunas  287.0   B      NaN         NaN    NaN
# 2  Lietuva    Klaipėda  147.0   C      NaN         NaN    NaN
# 3  Latvija        Ryga  716.0   D  Latvija   Daugpilis  105.0
# 4  Latvija  Ventspilis   43.0   E   Estija     Talinas  400.0
# 5  Latvija   Daugpilis  105.0   F   Estija       Tartu  101.0
# 6      NaN         NaN    NaN   X  Lietuva    Klaipėda  147.0
# 7      NaN         NaN    NaN   Y  Latvija        Ryga  716.0
# 8      NaN         NaN    NaN   Z  Latvija  Ventspilis   43.0

# %%
df1.join(df4, lsuffix='L', rsuffix='R')
# Out:
#     ŠalisL    MiestasL  GyvL keyL   ŠalisR    MiestasR   GyvR keyR
# 0  Lietuva     Vilnius   541    A      NaN         NaN    NaN  NaN
# 1  Lietuva      Kaunas   287    B      NaN         NaN    NaN  NaN
# 2  Lietuva    Klaipėda   147    C  Lietuva    Klaipėda  147.0    X
# 3  Latvija        Ryga   716    D  Latvija        Ryga  716.0    Y
# 4  Latvija  Ventspilis    43    E  Latvija  Ventspilis   43.0    Z
# 5  Latvija   Daugpilis   105    F  Latvija   Daugpilis  105.0    D

# %%
df1
# Out:
#      Šalis     Miestas  Gyv key
# 0  Lietuva     Vilnius  541   A
# 1  Lietuva      Kaunas  287   B
# 2  Lietuva    Klaipėda  147   C
# 3  Latvija        Ryga  716   D
# 4  Latvija  Ventspilis   43   E
# 5  Latvija   Daugpilis  105   F

# %%
df4
# Out:
#      Šalis     Miestas  Gyv key
# 2  Lietuva    Klaipėda  147   X
# 3  Latvija        Ryga  716   Y
# 4  Latvija  Ventspilis   43   Z
# 5  Latvija   Daugpilis  105   D
# 6   Estija     Talinas  400   E
# 7   Estija       Tartu  101   F

# %% [markdown]
# IMPORT

# %%
pd.read_csv("uzduotys/tops/top1-25-1.csv")
# Out:
#                                        Track.Name    Artist.Name  \
# 0                                        Senorita   Shawn Mendes
# 1                                           China       Anuel AA
# 2                   boyfriend (with Social House)  Ariana Grande
# 3                 Beautiful People (feat. Khalid)     Ed Sheeran
# 4                     Goodbyes (Feat. Young Thug)    Post Malone
# 5               I Don't Care (with Justin Bieber)     Ed Sheeran
# 6                                          Ransom      Lil Tecca
# 7                               How Do You Sleep?      Sam Smith
# 8                           Old Town Road - Remix      Lil Nas X
# 9                                         bad guy  Billie Eilish
# 10                                       Callaita      Bad Bunny
# 11          Loco Contigo (feat. J. Balvin & Tyga)       DJ Snake
# 12                              Someone You Loved  Lewis Capaldi
# 13                             Otro Trago - Remix           Sech
# 14       Money In The Grave (Drake ft. Rick Ross)          Drake
# 15                      No Guidance (feat. Drake)    Chris Brown
# 16                                     LA CANCION       J Balvin
# 17  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 18                                         Lalala            Y2K
# 19                                    Truth Hurts          Lizzo
# 20                            Piece Of Your Heart         MEDUZA
# 21                                         Panini      Lil Nas X
# 22                           No Me Conoce - Remix    Jhay Cortez
# 23                                Soltera - Remix          Lunay
# 24                   bad guy (with Justin Bieber)  Billie Eilish
#
#                Genre  Popularity
# 0       canadian pop        79.0
# 1     reggaeton flow        92.0
# 2          dance pop        85.0
# 3                pop         NaN
# 4            dfw rap        94.0
# 5                pop        84.0
# 6         trap music        92.0
# 7                pop        90.0
# 8        country rap        87.0
# 9         electropop        95.0
# 10         reggaeton        93.0
# 11         dance pop        86.0
# 12               pop        88.0
# 13    panamanian pop        87.0
# 14  canadian hip hop        92.0
# 15         dance pop        82.0
# 16             latin        90.0
# 17           dfw rap        91.0
# 18               NaN        88.0
# 19       escape room        91.0
# 20         pop house        91.0
# 21       country rap        91.0
# 22    reggaeton flow        83.0
# 23             latin        91.0
# 24        electropop         NaN
